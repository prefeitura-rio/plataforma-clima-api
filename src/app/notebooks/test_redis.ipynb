# %%
import redis

# Connect to Redis running in Docker on a different port
# redis_client = redis.Redis(host='my-redis', port=6379, db=0)
# redis_client = redis.Redis(host='redis', port=6379, db=0)
redis_client = redis.Redis(host='localhost', port=6379, db=0)
# Test the connection
# r.set('key', 'value')

print(redis_client.get('cp'))
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/Documentos/Work/escritorio_dados/esc_venv_310/lib/python3.10/site-packages/redis/connection.py:707, in AbstractConnection.connect(self)
#     706 try:
# --> 707     sock = self.retry.call_with_retry(
#     708         lambda: self._connect(), lambda error: self.disconnect(error)
#     709     )
#     710 except socket.timeout:
#
# File ~/Documentos/Work/escritorio_dados/esc_venv_310/lib/python3.10/site-packages/redis/retry.py:46, in Retry.call_with_retry(self, do, fail)
#      45 try:
# ---> 46     return do()
#      47 except self._supported_errors as error:
#
# File ~/Documentos/Work/escritorio_dados/esc_venv_310/lib/python3.10/site-packages/redis/connection.py:708, in AbstractConnection.connect.<locals>.<lambda>()
#     706 try:
#     707     sock = self.retry.call_with_retry(
# --> 708         lambda: self._connect(), lambda error: self.disconnect(error)
#     709     )
#     710 except socket.timeout:
#
# File ~/Documentos/Work/escritorio_dados/esc_venv_310/lib/python3.10/site-packages/redis/connection.py:974, in Connection._connect(self)
#     973 err = None
# --> 974 for res in socket.getaddrinfo(
#     975     self.host, self.port, self.socket_type, socket.SOCK_STREAM
#     976 ):
#     977     family, socktype, proto, canonname, socket_address = res
#
# File /usr/lib/python3.10/socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[5], line 10
#       6 redis_client = redis.Redis(host='my_redis', port=6379, db=0)
#       7 # Test the connection
#       8 # r.set('key', 'value')
# ---> 10 print(redis_client.get('cp'))
#
# File ~/Documentos/Work/escritorio_dados/esc_venv_310/lib/python3.10/site-packages/redis/commands/core.py:1816, in BasicKeyCommands.get(self, name)
#    1810 def get(self, name: KeyT) -> ResponseT:
#    1811     """
#    1812     Return the value at key ``name``, or None if the key doesn't exist
#    1813
#    1814     For more information see https://redis.io/commands/get
#    1815     """
# -> 1816     return self.execute_command("GET", name)
#
# File ~/Documentos/Work/escritorio_dados/esc_venv_310/lib/python3.10/site-packages/redis/client.py:1266, in Redis.execute_command(self, *args, **options)
#    1264 pool = self.connection_pool
#    1265 command_name = args[0]
# -> 1266 conn = self.connection or pool.get_connection(command_name, **options)
#    1268 try:
#    1269     return conn.retry.call_with_retry(
#    1270         lambda: self._send_command_parse_response(
#    1271             conn, command_name, *args, **options
#    1272         ),
#    1273         lambda error: self._disconnect_raise(conn, error),
#    1274     )
#
# File ~/Documentos/Work/escritorio_dados/esc_venv_310/lib/python3.10/site-packages/redis/connection.py:1461, in ConnectionPool.get_connection(self, command_name, *keys, **options)
#    1457     self._in_use_connections.add(connection)
#    1459 try:
#    1460     # ensure this connection is connected to Redis
# -> 1461     connection.connect()
#    1462     # connections that the pool provides should be ready to send
#    1463     # a command. if not, the connection was either returned to the
#    1464     # pool before all data has been read or the socket has been
#    1465     # closed. either way, reconnect and verify everything is good.
#    1466     try:
#
# File ~/Documentos/Work/escritorio_dados/esc_venv_310/lib/python3.10/site-packages/redis/connection.py:713, in AbstractConnection.connect(self)
#     711     raise TimeoutError("Timeout connecting to server")
#     712 except OSError as e:
# --> 713     raise ConnectionError(self._error_message(e))
#     715 self._sock = sock
#     716 try:
#
# ConnectionError: Error -3 connecting to my_redis:6379. Temporary failure in name resolution.

# %%
keys = redis_client.keys('*')  # O '*' é um padrão que corresponde a todas as chaves

print(keys)
# Printar todas as chaves
for key in keys:
    print(key.decode('utf-8'))
# Out:
# []

# %%
import json
import numpy as np
from datetime import datetime


log=print
def save_on_redis(
    redis_client,
    values,
    redis_hash: str = None,
    redis_key: str = None,
    keep_last: int = 50,
    sort_key: str = None,
) -> None:
    """
    Save values on redis. If values are a list, order ir and keep only last names.
    """
    print(values)
    if isinstance(values, list):
        # try:
        #     values = list(set(values))
        # except TypeError:
        #     log("I was not possible to use set() to filter duplicates on this list.")
        # values = sorted(values, key=sort_key)
        log(f"\n\nBefore keep_last {values}\n\n")
        values = values[-keep_last:]

    if isinstance(values, dict):
        values = json.dumps(values)
    values = json.dumps(values)

    log(f"Saving files {values} on redis {redis_hash} {redis_key}")

    if redis_hash and redis_key:
        redis_client.hset(redis_hash, redis_key, values)
    elif redis_key:
        redis_client.set(redis_key, values)
    log(f"Saved to Redis hash: {redis_hash}, key: {redis_key}, value: {values}")


def sort_list_by_dict_key(item, key: str = "timestamp") -> datetime:
    """
    Sorts a list of dictionaries based on a specified key.

    Parameters:
    item (dict): A dictionary inside a list to be sorted.
    key (str, optional): The key to sort the list by. Defaults to "timestamp".

    Returns:
    datetime.datetime: The sorted datetime object based on the specified key.
    """
    return datetime.fromisoformat(item[key])

point_values_updated = [[{'timestamp': '2025-01-09 09:00:20', 'valor': np.nan}, {'timestamp': '2025-01-09 09:10:20', 'valor': 0.0}, {'timestamp': '2025-01-09 09:20:20', 'valor': 0.0}, {'timestamp': '2025-01-09 09:30:20', 'valor': 0.0}, {'timestamp': '2025-01-09 09:40:20', 'valor': 0.0}, {'timestamp': '2025-01-09 09:50:20', 'valor': 0.0}, {'timestamp': '2025-01-09 10:00:20', 'valor': 0.19902298821428568}, {'timestamp': '2025-01-09 10:10:20', 'valor': 0.0}, {'timestamp': '2025-01-09 10:20:20', 'valor': 0.05370461586734693}, {'timestamp': '2025-01-09 10:30:20', 'valor': 0.0}, {'timestamp': '2025-01-09 10:40:20', 'valor': 0.0}, {'timestamp': '2025-01-09 10:50:20', 'valor': 0.0}]]
save_on_redis(
            redis_client,
            values=point_values_updated,
            redis_key="cp",
            keep_last=12,
            sort_key=sort_list_by_dict_key,
            )
# Out:
# [[{'timestamp': '2025-01-09 09:00:20', 'valor': nan}, {'timestamp': '2025-01-09 09:10:20', 'valor': 0.0}, {'timestamp': '2025-01-09 09:20:20', 'valor': 0.0}, {'timestamp': '2025-01-09 09:30:20', 'valor': 0.0}, {'timestamp': '2025-01-09 09:40:20', 'valor': 0.0}, {'timestamp': '2025-01-09 09:50:20', 'valor': 0.0}, {'timestamp': '2025-01-09 10:00:20', 'valor': 0.19902298821428568}, {'timestamp': '2025-01-09 10:10:20', 'valor': 0.0}, {'timestamp': '2025-01-09 10:20:20', 'valor': 0.05370461586734693}, {'timestamp': '2025-01-09 10:30:20', 'valor': 0.0}, {'timestamp': '2025-01-09 10:40:20', 'valor': 0.0}, {'timestamp': '2025-01-09 10:50:20', 'valor': 0.0}]]
#
#
